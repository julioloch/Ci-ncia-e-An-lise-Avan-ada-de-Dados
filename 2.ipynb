# %%
import numpy as np
import matplotlib.pyplot as plt

tamanho_populacao = 1000
np.random.seed(2006)
dados_populacao = np.random.normal(loc=100, scale=2, size=tamanho_populacao)

plt.hist(dados_populacao)
plt.xlabel("Altura")
plt.ylabel("Quantidade")
# Out:
# Text(0, 0.5, 'Quantidade')
